# %%
import joblib, numpy as np, pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import (classification_report, roc_auc_score,
                              RocCurveDisplay, accuracy_score)
import time, tracemalloc

# %%
X_train, X_test, y_train, y_test = joblib.load('data/train_test_split.pkl')

# %% [markdown]
# # Load All Models

# %%
models = {
    'Logistic Regression': joblib.load('data/lr_model.pkl'),
    'Random Forest':       joblib.load('data/rf_model.pkl'),   # ready when M2 done
    'KNN':                 joblib.load('data/knn_model.pkl'),   # ready when M3 done
    'Decision Tree':       joblib.load('data/dt_model.pkl'),    # ready when M4 done
}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 models = {
#       2     'Logistic Regression': joblib.load('data/lr_model.pkl'),
# ----> 3     'Random Forest':       joblib.load('data/rf_model.pkl'),   # ready when M2 done
#       4     'KNN':                 joblib.load('data/knn_model.pkl'),   # ready when M3 done
#       5     'Decision Tree':       joblib.load('data/dt_model.pkl'),    # ready when M4 done
#       6 }
#
# File /opt/anaconda3/lib/python3.13/site-packages/joblib/numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
# ...

# %% [markdown]
# # Comparative Metrics Table

# %%
results = []
for name, model in models.items():
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:,1]
    results.append({
        'Model': name,
        'Accuracy': round(accuracy_score(y_test, y_pred), 4),
        'ROC-AUC': round(roc_auc_score(y_test, y_prob), 4),
    })

pd.DataFrame(results).sort_values('ROC-AUC', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 results = []
# ----> 2 for name, model in models.items():
#       3     y_pred = model.predict(X_test)
#       4     y_prob = model.predict_proba(X_test)[:,1]
#
# NameError: name 'models' is not defined

# %% [markdown]
# # All ROC Curves on One Plot

# %%
fig, ax = plt.subplots(figsize=(8, 6))
for name, model in models.items():
    RocCurveDisplay.from_estimator(model, X_test, y_test, ax=ax, name=name)
ax.plot([0,1],[0,1],'k--')
ax.set_title('ROC Curve Comparison — All Models')
plt.tight_layout()
plt.savefig('data/all_roc_curves.png', dpi=150)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 fig, ax = plt.subplots(figsize=(8, 6))
# ----> 2 for name, model in models.items():
#       3     RocCurveDisplay.from_estimator(model, X_test, y_test, ax=ax, name=name)
#       4 ax.plot([0,1],[0,1],'k--')
#
# NameError: name 'models' is not defined
